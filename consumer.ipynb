# %% [markdown]
# ## **Build Connection MongoDB**

# %%
from pymongo import MongoClient

try:
    server = MongoClient('mongodb://YOUR_USERNAME:YOUR_PASSWORD@YOUR_HOST:YOUR_PORT/')

    db = server.admin
    server_status = db.command("ping")
    print("MongoDB connection successful:", server_status)

    databases = server.list_database_names()
    print("Databases:", databases)

except Exception as e:
    print("An error occurred:", e)
# Out:
# MongoDB connection successful: {'ok': 1.0}
# Databases: ['admin', 'config', 'ftde02', 'ftde3', 'local']

# %% [markdown]
# ## **Load Data New Information From Kafka Producer**

# %%
# 1. Ambil Data dari Kafka Producer
# 4. Insert kedalam MongoDB

# %%
import json
import pandas as pd
from kafka import KafkaConsumer

if __name__ == "__main__":
    consumer = KafkaConsumer("testing", bootstrap_servers='34.56.65.122')
    print("Starting the consumer")
    
    for msg in consumer:
        print(f"Records = {json.loads(msg.value)}")
        
        # Parsing pesan Kafka
        data = json.loads(msg.value)
        df = pd.DataFrame([data])
        
        # #join old information di postgreSQL
        # data = produder.merge(df, how='inner', on=['nameOrig','nameDest'])

        # data_predict = data.drop(['nameOrig','nameDest'], axis=1)
        # data_predict = data_predict.to_dict('index')[0]

        # print(path)
        # result = FraudModel.runModel(data_predict, path)
        # data['predict'] = result
        
        #insert mongodb
        db = server["ftde3"]
        collection = db["testing"]

        if isinstance(df.to_dict('index')[0], list):
            collection.insert_many(df.to_dict('index')[0])
        else:
            collection.insert_one(df.to_dict('index')[0])        
            print("Data telah disimpan ke MongoDB")
# Out:
# Starting the consumer
# Records = {'CandidateID': 7, 'Name': 'Sarah Perry DDS', 'Gender': 'Female', 'Age': 42, 'Position': 'Network Administrator', 'ApplicationDate': '2024-03-25', 'Status': 'Interviewed', 'InterviewDate': nan, 'OfferStatus': 'Hired'}
# Data telah disimpan ke MongoDB
# Records = {'CandidateID': 8, 'Name': 'Patrick Reynolds', 'Gender': 'Female', 'Age': 60, 'Position': 'UI/UX Designer', 'ApplicationDate': '2024-04-20', 'Status': 'Interviewed', 'InterviewDate': nan, 'OfferStatus': nan}
# Data telah disimpan ke MongoDB
# Records = {'CandidateID': 9, 'Name': 'Brian Wells', 'Gender': 'Female', 'Age': 36, 'Position': 'IT Manager', 'ApplicationDate': '2024-02-25', 'Status': 'Interviewed', 'InterviewDate': '2023-12-27', 'OfferStatus': 'Hired'}
# Data telah disimpan ke MongoDB
# ...

# %% [markdown]
# ## **Load MongoDB Collection**

# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np

try:
    # Connect to MongoDB server
    server = MongoClient('mongodb://YOUR_USERNAME:YOUR_PASSWORD@YOUR_HOST:YOUR_PORT/')
    
    # Verify the connection
    db = server.admin
    server_status = db.command("ping")
    print("MongoDB connection successful:", server_status)

    # Access a specific database
    database_name = "ftde3"  # Replace with your database name
    db = server[database_name]
    print(f"Using database: {database_name}")

    # Access a specific collection
    collection_name = "testing"  # Replace with your collection name
    collection = db[collection_name]

    # Query the collection (fetch first 5 documents)
    documents = collection.find()

    # Convert documents to a DataFrame
    data_list = list(documents)  # Convert cursor to a list
    df = pd.DataFrame(data_list)  # Create a DataFrame from the list

    print("Data saved into DataFrame")

except Exception as e:
    print("An error occurred:", e)
# Out:
# MongoDB connection successful: {'ok': 1.0}
# Using database: ftde3
# Data saved into DataFrame

# %%
df.head(5)
# Out:
#                         _id  CandidateID              Name  Gender  Age  \
# 0  676835dbb144ffbb2265190a            7   Sarah Perry DDS  Female   42
# 1  676835dfb144ffbb2265190b            8  Patrick Reynolds  Female   60
# 2  676835e5b144ffbb2265190c            9       Brian Wells  Female   36
# 3  676835e9b144ffbb2265190d           10     Connie Coffey  Female   55
# 4  676835efb144ffbb2265190e           11     Anthony Riley  Female   56
#
#                  Position ApplicationDate       Status InterviewDate  \
# 0   Network Administrator      2024-03-25  Interviewed          None
# 1          UI/UX Designer      2024-04-20  Interviewed          None
# 2              IT Manager      2024-02-25  Interviewed    2023-12-27
# 3  Database Administrator      2023-12-27     Rejected    2023-09-29
# 4   Network Administrator      2024-06-02     Rejected    2023-12-05
#
#   OfferStatus
# 0       Hired
# 1        None
# 2       Hired
# 3       Hired
# 4       Hired

# %%
df = df.replace([np.nan, np.inf, -np.inf], None)

# %%
# !pwd
# Out:
# /Users/jeannetaoliviasantoso/final_project
